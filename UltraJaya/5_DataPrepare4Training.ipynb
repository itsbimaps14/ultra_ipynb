# %% [markdown]
# ## **Load Root Google Drive File dan Import Library**

# %%
## Load Folder Drive
import os, sys
from google.colab import drive
drive.mount('/content/drive/')

## Move Pointer File ke DATA_UM
# %cd /content/drive/MyDrive/DATA_UM

## Declare Root Project File
root_file = "/content/drive/MyDrive/DATA_UM"
# Out:
# Mounted at /content/drive/
# /content/drive/MyDrive/DATA_UM

# %%
# Import Important Library
import pandas as pd
import os.path
from os import path

# %% [markdown]
# ## **STRUCTURE CHANGES TO MATCH TRAINING DATA REQUIREMENT**

# %%
## Declare Hashtag Data
hashtag = "ultramilkxstraykids"

# %%
# Load Data for Training
df = pd.read_excel('data/label/'+hashtag+'/labeled_'+hashtag+'_dummy.xlsx')

# Rename column previous index as id_tweet for reporting purposes
df.rename( columns={'Unnamed: 0':'id_tweet'}, inplace=True)

# Show Data
df.head(10)
# Out:
#    id_tweet                        date  is-retweet               name  \
# 0         0  Oct 31, 2023 · 1:04 PM UTC        True    Make Your Move!
# 1         1  Nov 2, 2023 · 11:45 PM UTC       False              Lau^^
# 2         2   Nov 1, 2023 · 1:31 AM UTC        True  FELIX INDONESIA🇲🇨
# 3         3  Nov 2, 2023 · 10:20 AM UTC        True     Miho₋stay🐥🇯🇵🇮🇩
# 4         4   Nov 2, 2023 · 5:12 PM UTC        True          cilul 樂 ★
# 5         5   Nov 1, 2023 · 4:11 AM UTC        True  Felix 필릭스 Central
# 6         6   Nov 1, 2023 · 4:10 AM UTC        True              아리야 💜
# 7         7   Nov 2, 2023 · 4:14 PM UTC       False     Rika Kristanti
# 8         8   Nov 1, 2023 · 4:25 AM UTC        True              아리야 💜
# 9         9   Nov 2, 2023 · 4:01 PM UTC       False           Lily ᰔᩚ★
#
#         username           profile_id  comments  retweets  quotes  likes  \
# 0      @ultramym  1197372091978276864         6       783      57   1809
# 1  @Seungminlock  1645021719734923264         0         0       0      1
# 2    @LeeFelixID  1641970160700657670         3       839     119   2288
# 3   @Miho825_jkt  1665330990305406976         7         4       0     76
# 4     @youtiflul  1716136049519525888         0         2       0      4
# 5    @FLXCentral  1661136104861601792         1       148       5    825
# 6  @mycheese2123  1720666305182007296         0         2       1      2
# 7     @r1k6_chan           3354220506         0         0       0      0
# 8  @mycheese2123  1720666305182007296         0         6       1     12
# 9   @dandeliknow  1699752273403113472         1         0       0      0
#
#                                                 text  \
# 0  Btw, bakal ada premiere video #UltraMilkXStray...
# 1  Naik krl di pagi hari yg cerah, sambil ngeliat...
# 2  [🐣]  Wah pagi-pagi udah disambut @Stray_Kids d...
# 3  本日のウルトラミルクチャレンジは、 RASA KARAMEL=キャラメル味！  とっても甘く...
# 4  oh that's why they're holding the mocha flavor...
# 5  -- #FELIX cut from Ultra Milk x Stray Kids   🔗...
# 6  우리 스키즈 🥳  #MakeYourMove #iamULTRAoddinary #Ult...
# 7  Finally i got unskippable ads... 😍😍   @ultramy...
# 8  우리 스키즈 🥳 I love ULTRAMILK 🩷  #MakeYourMove #ia...
# 9  dapet iklan #UltraMilkXStrayKids mana bisa dis...
#
#                                           text_final  polarity
# 0  ngomong-ngomong bakal premiere video besok jam...         1
# 1  naik krl pagi hari cerah lihat barudak skzmena...         1
# 2  pagi pagi sambut straykids sarinah rangka jadi...         3
# 3  rasa karamel im japanese living indonesia iamu...         4
# 4    thats why theyre holding the mocha flavored one         1
# 5  felix cut ultra milk stray kids ngkm iamultrao...         1
# 6  makeyourmove iamultraoddinary sclass straykids...         4
# 7  finally got unskippable ads ultramym straykids...         1
# 8  love ultramilk makeyourmove iamultraoddinary s...         4
# 9                                    iklan mana skip         1

# %% [markdown]
# ## **CREATE FOLDER AND EXPORT DATA**

# %%
# Check Path is Available if no Create Dir
if path.exists(root_file+'/data/training/'+hashtag) == False:
  os.makedirs(root_file+'/data/training/'+hashtag)
else :
  print("File Already Existed")
# Out:
# File Already Existed

# %%
# Export Data
df.to_csv('data/training/'+hashtag+'/'+hashtag+'.csv', index=False)
