# %% [markdown]
# ####Load Google Drive File

# %%
## Load Folder Drive
import os, sys
import os.path
from os import path
from google.colab import drive
drive.mount('/content/drive/')

## Move Pointer File ke DATA_UM
# %cd /content/drive/MyDrive/DATA_UM

## Declare Root Project File
root_file = "/content/drive/MyDrive/DATA_UM"
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
# /content/drive/MyDrive/DATA_UM

# %% [markdown]
# # **SECTION FOR DATA SCRAPING**

# %%
import pandas as pd
import json
import csv

# dframe = pd.read_csv('data_scraped/'+hashtag+'.csv')

# %% [markdown]
# # **SECTION FOR DATA CLEANING**

# %% [markdown]
# ####1. Data Transformation (Old Process) - Updated Data Transformasi di Collab yg berbeda di 1.2 beda tiap platform. Disini hanya tinggal load. (Do not delete cell)

# %%
import re

# %%
# df_twitter = pd.read_excel(open('data/label/RTP_FINAL_TWITTER.xlsx', 'rb'),sheet_name='dataset')
# df_twitter = df_twitter.loc[:, ~df_twitter.columns.str.contains('^Unnamed')]
# df_twitter = df_twitter[df_twitter['brand'] == 'ultramilk']
# df_twitter.reset_index(drop=True, inplace=True)
# df_twitter

# %%
# df_tiktok = pd.read_excel(open('data/label/RTP_FINAL_TIKTOK.xlsx', 'rb'),sheet_name='dataset')
# df_tiktok = df_tiktok.loc[:, ~df_tiktok.columns.str.contains('^Unnamed')]
# df_tiktok = df_tiktok[df_tiktok['brand'] == 'ultramilk']
# df_tiktok.reset_index(drop=True, inplace=True)
# df_tiktok

# %%
# df_ig = pd.read_excel(open('data/label/NOT_FINAL_IG.xlsx', 'rb'),sheet_name='dataset')
# df_ig = df_ig.loc[:, ~df_ig.columns.str.contains('^Unnamed')]
# df_ig = df_ig[df_ig['brand'] == 'ultramilk']
# df_ig = df_ig[df_ig['add'] != 'a']
# df_ig = df_ig[df_ig['labelling'] != 'not labelled']
# df_ig = df_ig.drop(columns=['lang', 'conf_score', 'add', 'id', 'comment type', 'post type', 'post owner'])
# df_ig = df_ig.drop(df_ig.columns[0], axis=1)
# df_ig.reset_index(drop=True, inplace=True)
# df_ig

# %%
# df_manipulation = pd.read_excel(open('data/label/negative_manipulation.xlsx', 'rb'),sheet_name='dataset')
# df_manipulation = df_manipulation.loc[:, ~df_manipulation.columns.str.contains('^Unnamed')]
# df_manipulation = df_manipulation[df_manipulation['brand'] != 'ultramilk']
# df_manipulation.reset_index(drop=True, inplace=True)
# df_manipulation['brand'] = "Manipulation"
# df_manipulation['hashtag'] = "Manipulation"
# df_manipulation

# %%
# def change_tag(text):
#     text = text.replace("[HASHTAG]", "#ultramilkxstraykids")
#     text = text.replace("[OFF_USERNAME]", "@ultramym")
#     text = text.replace("[BA_USERNAME]", "@realstraykids")
#     text = text.replace("[BA]", "StrayKids")
#     text = text.replace("[RASA1]", "full cream")
#     text = text.replace("[RASA2]", "coklat")
#     text = text.replace("[RASA3]", "strayberry")
#     text = text.replace("[RASA4]", "vanilla")
#     text = text.replace("[RASA5]", "full cream")
#     text = text.replace("[RASA6]", "coklat")
#     text = text.replace("[RASA7]", "strawberry")
#     text = text.replace("[RASA8]", "vanilla")
#     text = text.replace("[RASA9]", "full cream")
#     text = text.replace("[RASA10]", "coklat")
#     text = text.replace("[BRAND]", "ultramilk")
#     text = text.replace("[BRAND_LAWAN]", "indomilk")
#     text = text.replace("[BRAND_LAWAN2]", "frisianflag")
#     text = text.replace("[EVENT]", "ultramilkxstraykids")
#     text = text.replace("[WADAH]", "kotak")
#     text = text.replace("[PLESETAN_EVENT]", "ultramilkxplastik")
#     text = text.replace("[RASA11]", "strawberry")
#     text = text.replace("[HASHTAG_LAWAN]", "#indomilkxastro")
#     text = text.replace("[WADAH2]", "botol")
#     text = text.replace("[KELOMPOK]", "susu")
#     text = text.replace("[BRAND_LAWAN3]", "cimory")
#     text = text.replace("[EVENT_NAME]", "ultramilkxstraykids")
#     text = text.replace("[OFF_LAWAN]", "@indomilk")
#     text = text.replace("[PRODUK]", "Ultramilk 250ml")

#     return text

# ## Running
# df_manipulation['text'] = df_manipulation['text'].apply(lambda x: change_tag(x))

# ## Output Data
# df_manipulation

# %%
df_mention_straykids = pd.read_excel(open('mentionlytics/straykids_ultramilk_mentionlytics_predicted.xlsx', 'rb'),sheet_name='Sheet1')
df_mention_straykids = df_mention_straykids.loc[:, ~df_mention_straykids.columns.str.contains('^Unnamed')]
df_mention_straykids = df_mention_straykids[df_mention_straykids['true_sen'].notnull()]
df_mention_straykids.reset_index(drop=True, inplace=True)
df_mention_straykids
# Out:
#              ID                                               text sentiment  \
# 0    1422688196                             Sekarang masih ada gak  negative
# 1    1420799411  @@yjungwon di alfamart dan alfamidi.. bahkan d...  negative
# 2    1421922096  Salah ngomong ke mba kasirnya harusnya ultra m...   neutral
# 3    1418318177  sebulan penuh bersama ultramilk jaya jaya jaya...  positive
# 4    1418139889                    SEMOGA UDAH ADA DI DOM GUE HUHU  negative
# ..          ...                                                ...       ...
# 121  1378262812  Stop lewat di tl takut viral nanti malah langk...   neutral
# 122  1377906743                                   wkwkwkwk ya udah  negative
# 123  1377852724  pls gue lg menghilang dr peradaban kerjaan gue...   neutral
# 124  1377923265  SEKALIAN DEH HALO ULTRA MILK KM GAMAU BIKIN VA...  negative
# 125  1377830134  gk bisa bedain ultra milk low fat sama yg full...   neutral
#
#     predicted  true_sen
# 0     Neutral       1.0
# 1     Neutral       1.0
# 2    Negative       1.0
# 3    Negative       2.0
# 4     Neutral       1.0
# ..        ...       ...
# 121  Negative       1.0
# 122   Neutral       1.0
# 123  Negative       1.0
# 124   Neutral       1.0
# 125  Negative       1.0
#
# [126 rows x 5 columns]

# %%
df_mention_itzy = pd.read_excel(open('mentionlytics/itzy_ultramilk_mentionlytics_predicted.xlsx', 'rb'),sheet_name='Sheet1')
df_mention_itzy = df_mention_itzy.loc[:, ~df_mention_itzy.columns.str.contains('^Unnamed')]
df_mention_itzy = df_mention_itzy[df_mention_itzy['true_sen'].notnull()]
df_mention_itzy.reset_index(drop=True, inplace=True)
df_mention_itzy
# Out:
#             ID                                               text sentiment  \
# 0   1271792137  ITZY × ULTRA MILK #itzyultramilk #fyp #itzy #w...       NaN
# 1   1260258975  Pencarian masih berlanjut 🥰  - Itzy - Ultramil...       NaN
# 2   1248518423  Halo teman - teman, saya mau sharing nih, peng...  positive
# 3   1248518509  Halo teman - teman, saya mau sharing nih, peng...  positive
# 4   1247721531  Finally complete set 15/15 photocard ITZY. Per...  positive
# 5   1271792182  Seru banget jajan Ultra Milk sambil berburu ph...       NaN
# 6   1247170764  Drama unboxing photocard itzy😭🙏 #itzyxultramil...       NaN
# 7   1247126993  lupa record pas bayar😭 #ultramilkxitzy #FlexEv...       NaN
# 8   1271792228  unboxing PC ITZY X Ultramilk #itzy #ultramilk ...       NaN
# 9   1247127008  agak hedon ya beli susu 8 biji 🥲🥲 tapi ga papa...       NaN
# 10  1247127012  Yey!! Akhirnya dapat jugaa🥹🫶🏻💕 #itzy #itzyxult...       NaN
# 11  1281576977  hasil berburu pc itzy x ultra milk, dapet ryur...       NaN
# 12  1271792253  bismillah abis ini dpt yg ryujin ☺️🙏🏻 #itzy #u...       NaN
# 13  1247127015  4 out of 15! 11 more to go! Btw, kalo ada yg p...       NaN
#
#    predicted  true_sen
# 0    Neutral       1.0
# 1    Neutral       1.0
# 2   Negative       2.0
# 3   Negative       2.0
# 4   Negative       2.0
# 5    Neutral       2.0
# 6    Neutral       1.0
# 7    Neutral       1.0
# 8   Positive       1.0
# 9    Neutral       1.0
# 10   Neutral       1.0
# 11   Neutral       1.0
# 12   Neutral       1.0
# 13   Neutral       1.0

# %% [markdown]
# Load Data Twitter dan Tiktok sisanya menyusul.

# %%
df_clean = pd.concat([df_mention_straykids, df_mention_itzy], ignore_index=True)
df_clean = df_clean.dropna(subset=['text'])
df_clean
# Out:
#              ID                                               text sentiment  \
# 0    1422688196                             Sekarang masih ada gak  negative
# 1    1420799411  @@yjungwon di alfamart dan alfamidi.. bahkan d...  negative
# 2    1421922096  Salah ngomong ke mba kasirnya harusnya ultra m...   neutral
# 3    1418318177  sebulan penuh bersama ultramilk jaya jaya jaya...  positive
# 4    1418139889                    SEMOGA UDAH ADA DI DOM GUE HUHU  negative
# ..          ...                                                ...       ...
# 135  1247127008  agak hedon ya beli susu 8 biji 🥲🥲 tapi ga papa...       NaN
# 136  1247127012  Yey!! Akhirnya dapat jugaa🥹🫶🏻💕 #itzy #itzyxult...       NaN
# 137  1281576977  hasil berburu pc itzy x ultra milk, dapet ryur...       NaN
# 138  1271792253  bismillah abis ini dpt yg ryujin ☺️🙏🏻 #itzy #u...       NaN
# 139  1247127015  4 out of 15! 11 more to go! Btw, kalo ada yg p...       NaN
#
#     predicted  true_sen
# 0     Neutral       1.0
# 1     Neutral       1.0
# 2    Negative       1.0
# 3    Negative       2.0
# 4     Neutral       1.0
# ..        ...       ...
# 135   Neutral       1.0
# 136   Neutral       1.0
# 137   Neutral       1.0
# 138   Neutral       1.0
# 139   Neutral       1.0
#
# [140 rows x 5 columns]

# %%
print(len(df_clean[df_clean['true_sen'] == 0]))
print(len(df_clean[df_clean['true_sen'] == 1]))
print(len(df_clean[df_clean['true_sen'] == 2]))
# Out:
# 18
# 62
# 60

# %% [markdown]
# ####2. Text Transformation
# 1. Delete Punctuations,
# 2. Delete Number,
# 3. Delete Link Website,
# 4. Delete Hashtag,
# 5. Transform to Lowercase,
# 6. Replace newline with space,
# 7. Delete Repeated Char,
# 8. Delete single word (moved to after stopword), dan
# 9. Replace double space.

# %%
# Import Lib String
import string

# %%
# Before Remove Punctuation
df_clean.head(10)
# Out:
#            ID                                               text sentiment  \
# 0  1422688196                             Sekarang masih ada gak  negative
# 1  1420799411  @@yjungwon di alfamart dan alfamidi.. bahkan d...  negative
# 2  1421922096  Salah ngomong ke mba kasirnya harusnya ultra m...   neutral
# 3  1418318177  sebulan penuh bersama ultramilk jaya jaya jaya...  positive
# 4  1418139889                    SEMOGA UDAH ADA DI DOM GUE HUHU  negative
# 5  1408883912                                    Ada pc gak ya??  negative
# 6  1402119207        Aku kira photocard straykids ternyata bukan  negative
# 7  1401585208  Movers lagi pada ngapain nih? Apapun aktivitas...  positive
# 8  1401241810  @hanIogys Mohon maaf atas ketidaknyamannya, Mo...  positive
# 9  1401241824  @darkbiy Halo, Movers. Mohon maaf atas kekecew...  positive
#
#   predicted  true_sen
# 0   Neutral       1.0
# 1   Neutral       1.0
# 2  Negative       1.0
# 3  Negative       2.0
# 4   Neutral       1.0
# 5   Neutral       1.0
# 6   Neutral       1.0
# 7  Negative       2.0
# 8  Negative       1.0
# 9  Negative       1.0

# %%
def remove_punct(text):
    text = str(text)

    ## TEXT TRANSFORM
    # Remove username 1st
    text = re.sub('@[^\s]+','',text)
    # Remove hashtag dan @
    ''.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)"," ",text).split())
    # Change "-" to space
    text = text.replace("-", " ")
    # Remove punctiation
    text  = "".join([char for char in text if char not in string.punctuation])
    # Remove angka
    text = re.sub('[0-9]+', '', text)
    # Remove website link
    text = re.sub(r'http\S+', '', text)
    # Remove new line
    text = re.sub("\n"," ",text)
    # Transform to lowercase
    text = text.lower()
    # Replace perulangan huruf pada kalimat "iyaaa" to "iya"
    text = re.sub(r'(\w)(\1{2,})', r"\1", text)
    # will replace single word
    text = re.sub(r"\b[a-zA-Z]\b","",text)
    # will replace space more than one
    text = re.sub('( {2,})',' ',text)

    return text

## Running
df_clean['text_punt'] = df_clean['text'].apply(lambda x: remove_punct(x))

## Show Data
df_clean.head(10)
# Out:
#            ID                                               text sentiment  \
# 0  1422688196                             Sekarang masih ada gak  negative
# 1  1420799411  @@yjungwon di alfamart dan alfamidi.. bahkan d...  negative
# 2  1421922096  Salah ngomong ke mba kasirnya harusnya ultra m...   neutral
# 3  1418318177  sebulan penuh bersama ultramilk jaya jaya jaya...  positive
# 4  1418139889                    SEMOGA UDAH ADA DI DOM GUE HUHU  negative
# 5  1408883912                                    Ada pc gak ya??  negative
# 6  1402119207        Aku kira photocard straykids ternyata bukan  negative
# 7  1401585208  Movers lagi pada ngapain nih? Apapun aktivitas...  positive
# 8  1401241810  @hanIogys Mohon maaf atas ketidaknyamannya, Mo...  positive
# 9  1401241824  @darkbiy Halo, Movers. Mohon maaf atas kekecew...  positive
#
#   predicted  true_sen                                          text_punt
# 0   Neutral       1.0                             sekarang masih ada gak
# 1   Neutral       1.0  yjungwon di alfamart dan alfamidi bahkan disur...
# 2  Negative       1.0  salah ngomong ke mba kasirnya harusnya ultra m...
# 3  Negative       2.0  sebulan penuh bersama ultramilk jaya jaya jaya...
# 4   Neutral       1.0                    semoga udah ada di dom gue huhu
# 5   Neutral       1.0                                      ada pc gak ya
# 6   Neutral       1.0        aku kira photocard straykids ternyata bukan
# 7  Negative       2.0  movers lagi pada ngapain nih apapun aktivitasn...
# 8  Negative       1.0  haniogys mohon maaf atas ketidaknyamannya move...
# 9  Negative       1.0  darkbiy halo movers mohon maaf atas kekecewaan...

# %% [markdown]
# ####3. Penghapusan Kata Singkatan, Slang, Alay, DLL

# %%
import string

# %%
df_tmp_nasalsabila = pd.read_csv('data/slang/colloquial-indonesian-lexicon_nasalsabila.csv')
df_slang_fendiirfan = pd.read_csv('data/slang/colloquial-indonesian-lexicon_fendiirfan.csv')
df_slang_custom = pd.read_csv('data/slang/custom_dictonary_slang.csv')
df_slang_custom_exception = pd.read_csv('data/slang/custom_dictonary_slang_dont_swap.csv')

# %%
## Transform and Delete Duplicate Data from nasalsabila
df_slang_nasalsabila = df_tmp_nasalsabila[['slang', 'formal']]
df_slang_nasalsabila.drop_duplicates(inplace=True)

## Transform and Delete Duplicate Data from fendiirfan
df_slang_fendiirfan.dropna(inplace=True)
df_slang_fendiirfan.rename(columns={'kataAlay': 'slang', 'kataBaik': 'formal'}, inplace=True)
df_slang_fendiirfan.drop_duplicates(inplace=True)

## Transform and Delete Duplicate our own data.
df_slang_custom.drop_duplicates(inplace=True)
df_slang_custom_exception.drop_duplicates(inplace=True)
# Out:
# <ipython-input-63-97e6cbf1b797>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_slang_nasalsabila.drop_duplicates(inplace=True)

# %%
############### Filter Slang awal (20 Menit)
# %%time

# def remove_slang(text):
#     # To Lowercase
#     text = " "+text.lower()+" "
#     for index, row in df_filter_slang.iterrows():
#       # Change Slang to Formal
#       # print(row['slang'], row['formal'])
#       # text = re.sub(r'\b%s\b' % row['slang'], row['formal'], text)
#       text = text.replace(' '+row['slang']+' ', ' '+row['formal']+' ')

#     text = text[1:]
#     text = text.rstrip(text[-1])
#     return text

# ## Testing
# #x = "yang yg dapat dpt blh boleh okay oke"
# #print(remove_slang(x))

# df_clean['text_filter'] = df_clean['text'].apply(lambda x: remove_slang(x))
# df_clean.head(10)

# %%
import numpy as np

# %%
# %%time

def remove_slang(text, df_tmp):
    # To Lowercase
    text = text.lower()

    # Pecah to array
    words = text.split(" ");

    # DF to Array
    arr_slang = df_tmp['slang'].to_numpy()
    arr_formal = df_tmp['formal'].to_numpy()
    do_not_change = df_slang_custom_exception['kata'].to_numpy()

    # Array New Text
    new_text = []

    for kata in words:
      if kata in arr_slang:
        if kata not in do_not_change:
          idx = np.where(arr_slang==kata)[0][0]
          kata = arr_formal[idx]

      new_text.append(kata)
      text_new = ' '.join(new_text)

    return text_new

## Testing
#x = "yang yg dapat dpt blh boleh okay oke"
#print(remove_slang(x))

## Running
df_clean['text_filter1'] = df_clean['text_punt'].apply(lambda x: remove_slang(x,df_slang_nasalsabila))
df_clean['text_filter2'] = df_clean['text_filter1'].apply(lambda x: remove_slang(x,df_slang_fendiirfan))
df_clean['text_filter'] = df_clean['text_filter2'].apply(lambda x: remove_slang(x,df_slang_custom))

## Delete Unused Column
df_clean.drop(columns=['text_punt', 'text_filter1', 'text_filter2'], inplace=True)

## Show Data
df_clean
# Out:
# CPU times: user 549 ms, sys: 25.1 ms, total: 574 ms
# Wall time: 565 ms
#              ID                                               text sentiment  \
# 0    1422688196                             Sekarang masih ada gak  negative
# 1    1420799411  @@yjungwon di alfamart dan alfamidi.. bahkan d...  negative
# 2    1421922096  Salah ngomong ke mba kasirnya harusnya ultra m...   neutral
# 3    1418318177  sebulan penuh bersama ultramilk jaya jaya jaya...  positive
# 4    1418139889                    SEMOGA UDAH ADA DI DOM GUE HUHU  negative
# ..          ...                                                ...       ...
# 135  1247127008  agak hedon ya beli susu 8 biji 🥲🥲 tapi ga papa...       NaN
# 136  1247127012  Yey!! Akhirnya dapat jugaa🥹🫶🏻💕 #itzy #itzyxult...       NaN
# 137  1281576977  hasil berburu pc itzy x ultra milk, dapet ryur...       NaN
# 138  1271792253  bismillah abis ini dpt yg ryujin ☺️🙏🏻 #itzy #u...       NaN
# 139  1247127015  4 out of 15! 11 more to go! Btw, kalo ada yg p...       NaN
#
#     predicted  true_sen                                        text_filter
# 0     Neutral       1.0                           sekarang masih ada tidak
# 1     Neutral       1.0  yjungwon di alfamart dan alfamidi bahkan disur...
# 2    Negative       1.0  salah mengomong ke mbak kasirnya harusnya ultr...
# 3    Negative       2.0  sebulan penuh bersama ultramilk jaya jaya jaya...
# 4     Neutral       1.0              semoga sudah ada di domisili aku haha
# ..        ...       ...                                                ...
# 135   Neutral       1.0  agak hedon ya beli susu biji 🥲🥲 tapi tidak pap...
# 136   Neutral       1.0  yey akhirnya dapat jugaa🥹🫶🏻💕 itzy itzyxultrami...
# 137   Neutral       1.0  hasil berburu photocard itzy ultra milk dapat ...
# 138   Neutral       1.0  bismillah habis ini dapat yang ryujin ☺️🙏🏻 itz...
# 139   Neutral       1.0   out of more tapi go ngomong-ngomong jika ada ...
#
# [140 rows x 6 columns]

# %% [markdown]
# ####4. Stemming Sentence

# %%
## Donwload Library Sastrawi for Stemming and Stopword
# !pip install Sastrawi
# Out:
# Collecting Sastrawi
#   Downloading Sastrawi-1.0.1-py2.py3-none-any.whl (209 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.7/209.7 kB 5.5 MB/s eta 0:00:00
# Installing collected packages: Sastrawi
# Successfully installed Sastrawi-1.0.1

# %%
# Import StemmerFactory class
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

# Create Stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# %%
# %%time

def stemming_sentence(text):
    text = stemmer.stem(text)
    return text

## Running
df_clean['text_stemming'] = df_clean['text_filter'].apply(lambda x: stemming_sentence(x))

## Delete Unused Column
df_clean.drop(columns=['text_filter'], inplace=True)

## Show Data
df_clean
# Out:
# CPU times: user 1min 8s, sys: 216 ms, total: 1min 8s
# Wall time: 1min 14s
#              ID                                               text sentiment  \
# 0    1422688196                             Sekarang masih ada gak  negative
# 1    1420799411  @@yjungwon di alfamart dan alfamidi.. bahkan d...  negative
# 2    1421922096  Salah ngomong ke mba kasirnya harusnya ultra m...   neutral
# 3    1418318177  sebulan penuh bersama ultramilk jaya jaya jaya...  positive
# 4    1418139889                    SEMOGA UDAH ADA DI DOM GUE HUHU  negative
# ..          ...                                                ...       ...
# 135  1247127008  agak hedon ya beli susu 8 biji 🥲🥲 tapi ga papa...       NaN
# 136  1247127012  Yey!! Akhirnya dapat jugaa🥹🫶🏻💕 #itzy #itzyxult...       NaN
# 137  1281576977  hasil berburu pc itzy x ultra milk, dapet ryur...       NaN
# 138  1271792253  bismillah abis ini dpt yg ryujin ☺️🙏🏻 #itzy #u...       NaN
# 139  1247127015  4 out of 15! 11 more to go! Btw, kalo ada yg p...       NaN
#
#     predicted  true_sen                                      text_stemming
# 0     Neutral       1.0                           sekarang masih ada tidak
# 1     Neutral       1.0  yjungwon di alfamart dan alfamidi bahkan suruh...
# 2    Negative       1.0  salah omong ke mbak kasir harus ultra milk eh ...
# 3    Negative       2.0  bulan penuh sama ultramilk jaya jaya jaya haha...
# 4     Neutral       1.0                moga sudah ada di domisili aku haha
# ..        ...       ...                                                ...
# 135   Neutral       1.0  agak hedon ya beli susu biji tapi tidak papa s...
# 136   Neutral       1.0  yey akhir dapat jugaa itzy itzyxultramilk dont...
# 137   Neutral       1.0  hasil buru photocard itzy ultra milk dapat ryu...
# 138   Neutral       1.0  bismillah habis ini dapat yang ryujin itzy ult...
# 139   Neutral       1.0  out of more tapi go ngomong-ngomong jika ada y...
#
# [140 rows x 6 columns]

# %% [markdown]
# #### 5. Remove Stopwords

# %%
## Load Library Stopword for Indonesian Language Sastrawi
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
factory = StopWordRemoverFactory()
stopword = factory.create_stop_word_remover()

# %%
# Load Data Stopword and Custom Word
stopword_satya = list(pd.read_csv('data/stopword/stopwords_satya.txt', header = None)[0])
custom_stopword = list(pd.read_csv('data/stopword/custom_stopword.txt', header = None)[0])
keep_custom_stopword = list(pd.read_csv('data/stopword/keep_custom_stopword.txt', header = None)[0])

# %%
def remove_stopwords(text):
  # Removal Stopword
  text_split = text.split(' ')

  temp_text_split = []
  for i in range(len(text_split)):
    ## Remove Stopword by Satwa : gak dipake dulu ini terlalu ngilangin konteks text
    #if (text_split[i] not in stopword_satya) and (text_split[i] not in custom_stopword):
    if (text_split[i] not in custom_stopword):
      ## Keep Beberapa Kata Valence of a text
      # https://datascience.stackexchange.com/questions/15765/nlp-why-is-not-a-stop-word#:~:text=Stop%20words%20are%20usually%20thought,idf%20analysis%20for%20document%20classification).
      if (text_split[i] in keep_custom_stopword) :
        temp_text_split.append(text_split[i])
      else :
        ## Stopword Removal from data by Sastrawi
        tmp = stopword.remove(text_split[i])
        temp_text_split.append(tmp)

  final_text = ' '.join(temp_text_split)

  # will replace single word
  final_text = re.sub(r"\b[a-zA-Z]\b","",final_text)

  # will replace space more than one
  final_text = re.sub("( {2,})"," ",final_text)

  return final_text

## Running
df_clean['text_final'] = df_clean['text_stemming'].apply(lambda x: remove_stopwords(x))

## Delete Unused Column
df_clean.drop(columns=['text_stemming'], inplace=True)

## Show Data
df_clean
# Out:
#              ID                                               text sentiment  \
# 0    1422688196                             Sekarang masih ada gak  negative
# 1    1420799411  @@yjungwon di alfamart dan alfamidi.. bahkan d...  negative
# 2    1421922096  Salah ngomong ke mba kasirnya harusnya ultra m...   neutral
# 3    1418318177  sebulan penuh bersama ultramilk jaya jaya jaya...  positive
# 4    1418139889                    SEMOGA UDAH ADA DI DOM GUE HUHU  negative
# ..          ...                                                ...       ...
# 135  1247127008  agak hedon ya beli susu 8 biji 🥲🥲 tapi ga papa...       NaN
# 136  1247127012  Yey!! Akhirnya dapat jugaa🥹🫶🏻💕 #itzy #itzyxult...       NaN
# 137  1281576977  hasil berburu pc itzy x ultra milk, dapet ryur...       NaN
# 138  1271792253  bismillah abis ini dpt yg ryujin ☺️🙏🏻 #itzy #u...       NaN
# 139  1247127015  4 out of 15! 11 more to go! Btw, kalo ada yg p...       NaN
#
#     predicted  true_sen                                         text_final
# 0     Neutral       1.0                                     sekarang tidak
# 1     Neutral       1.0  yjungwon alfamart alfamidi bahkan suruh ambil ...
# 2    Negative       1.0  salah omong mbak kasir ultra milk bahkan indom...
# 3    Negative       2.0  bulan penuh sama ultramilk jaya jaya jaya haha...
# 4     Neutral       1.0                             moga domisili aku haha
# ..        ...       ...                                                ...
# 135   Neutral       1.0   hedon beli susu biji tidak papa seru wkwkwk u...
# 136   Neutral       1.0  yey akhir jugaa itzy itzyxultramilk dontstopyo...
# 137   Neutral       1.0  hasil buru photocard itzy ultra milk ryuryeong...
# 138   Neutral       1.0  bismillah habis ryujin itzy ultramilkxitzy don...
# 139   Neutral       1.0  out of more go ngomong-ngomong photocard kemba...
#
# [140 rows x 6 columns]

# %% [markdown]
# ####6. Tokenization (Commented : Belum kepake di proses sampai saat ini)

# %%
# df_clean
# df_clean.to_csv('data_scraped/data_ok.csv')
# df_clean.to_excel('data_scraped/data_ok.xlsx')
# df_clean

# %%
df_clean
# Out:
#              ID                                               text sentiment  \
# 0    1422688196                             Sekarang masih ada gak  negative
# 1    1420799411  @@yjungwon di alfamart dan alfamidi.. bahkan d...  negative
# 2    1421922096  Salah ngomong ke mba kasirnya harusnya ultra m...   neutral
# 3    1418318177  sebulan penuh bersama ultramilk jaya jaya jaya...  positive
# 4    1418139889                    SEMOGA UDAH ADA DI DOM GUE HUHU  negative
# ..          ...                                                ...       ...
# 135  1247127008  agak hedon ya beli susu 8 biji 🥲🥲 tapi ga papa...       NaN
# 136  1247127012  Yey!! Akhirnya dapat jugaa🥹🫶🏻💕 #itzy #itzyxult...       NaN
# 137  1281576977  hasil berburu pc itzy x ultra milk, dapet ryur...       NaN
# 138  1271792253  bismillah abis ini dpt yg ryujin ☺️🙏🏻 #itzy #u...       NaN
# 139  1247127015  4 out of 15! 11 more to go! Btw, kalo ada yg p...       NaN
#
#     predicted  true_sen                                         text_final
# 0     Neutral       1.0                                     sekarang tidak
# 1     Neutral       1.0  yjungwon alfamart alfamidi bahkan suruh ambil ...
# 2    Negative       1.0  salah omong mbak kasir ultra milk bahkan indom...
# 3    Negative       2.0  bulan penuh sama ultramilk jaya jaya jaya haha...
# 4     Neutral       1.0                             moga domisili aku haha
# ..        ...       ...                                                ...
# 135   Neutral       1.0   hedon beli susu biji tidak papa seru wkwkwk u...
# 136   Neutral       1.0  yey akhir jugaa itzy itzyxultramilk dontstopyo...
# 137   Neutral       1.0  hasil buru photocard itzy ultra milk ryuryeong...
# 138   Neutral       1.0  bismillah habis ryujin itzy ultramilkxitzy don...
# 139   Neutral       1.0  out of more go ngomong-ngomong photocard kemba...
#
# [140 rows x 6 columns]

# %%
# Download Library NLTK untuk Tokenizernya.
# !pip install nltk

# Import Lib NLTK dan Tokenizer
import nltk
nltk.download("popular")
from nltk.tokenize import word_tokenize
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2023.12.25)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.2)
# [nltk_data] Downloading collection 'popular'
# [nltk_data]    |
# [nltk_data]    | Downloading package cmudict to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cmudict.zip.
# [nltk_data]    | Downloading package gazetteers to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gazetteers.zip.
# [nltk_data]    | Downloading package genesis to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/genesis.zip.
# [nltk_data]    | Downloading package gutenberg to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gutenberg.zip.
# [nltk_data]    | Downloading package inaugural to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/inaugural.zip.
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/movie_reviews.zip.
# [nltk_data]    | Downloading package names to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/names.zip.
# [nltk_data]    | Downloading package shakespeare to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/shakespeare.zip.
# [nltk_data]    | Downloading package stopwords to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/stopwords.zip.
# [nltk_data]    | Downloading package treebank to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/treebank.zip.
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/twitter_samples.zip.
# [nltk_data]    | Downloading package omw to /root/nltk_data...
# [nltk_data]    | Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]    | Downloading package wordnet to /root/nltk_data...
# [nltk_data]    | Downloading package wordnet2021 to /root/nltk_data...
# [nltk_data]    | Downloading package wordnet31 to /root/nltk_data...
# [nltk_data]    | Downloading package wordnet_ic to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/wordnet_ic.zip.
# [nltk_data]    | Downloading package words to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/words.zip.
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping chunkers/maxent_ne_chunker.zip.
# [nltk_data]    | Downloading package punkt to /root/nltk_data...
# [nltk_data]    |   Unzipping tokenizers/punkt.zip.
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data]    |
# [nltk_data]  Done downloading collection popular

# %%
# def tokenization(text):
#     word_token = word_tokenize(text)
#     return word_token

# df_clean['text_token'] = df_clean['text_stemming'].apply(lambda x: tokenization(x.lower()))
# df_clean.head(10)

# %% [markdown]
# #### [LAST] Save Data Checkpoint CSV

# %%
## Duplicate Dataframe
df_final = df_clean

## Delete NULL value in data after preprocessing
# Replace Data null to nan
df_final.replace(' ', np.nan, inplace=True)
df_final.replace('', np.nan, inplace=True)

# Delete Data nan
df_final.dropna(subset=['text_final'], inplace=True)

## Preview Data
df_final
# Out:
#              ID                                               text sentiment  \
# 0    1422688196                             Sekarang masih ada gak  negative
# 1    1420799411  @@yjungwon di alfamart dan alfamidi.. bahkan d...  negative
# 2    1421922096  Salah ngomong ke mba kasirnya harusnya ultra m...   neutral
# 3    1418318177  sebulan penuh bersama ultramilk jaya jaya jaya...  positive
# 4    1418139889                    SEMOGA UDAH ADA DI DOM GUE HUHU  negative
# ..          ...                                                ...       ...
# 135  1247127008  agak hedon ya beli susu 8 biji 🥲🥲 tapi ga papa...       NaN
# 136  1247127012  Yey!! Akhirnya dapat jugaa🥹🫶🏻💕 #itzy #itzyxult...       NaN
# 137  1281576977  hasil berburu pc itzy x ultra milk, dapet ryur...       NaN
# 138  1271792253  bismillah abis ini dpt yg ryujin ☺️🙏🏻 #itzy #u...       NaN
# 139  1247127015  4 out of 15! 11 more to go! Btw, kalo ada yg p...       NaN
#
#     predicted  true_sen                                         text_final
# 0     Neutral       1.0                                     sekarang tidak
# 1     Neutral       1.0  yjungwon alfamart alfamidi bahkan suruh ambil ...
# 2    Negative       1.0  salah omong mbak kasir ultra milk bahkan indom...
# 3    Negative       2.0  bulan penuh sama ultramilk jaya jaya jaya haha...
# 4     Neutral       1.0                             moga domisili aku haha
# ..        ...       ...                                                ...
# 135   Neutral       1.0   hedon beli susu biji tidak papa seru wkwkwk u...
# 136   Neutral       1.0  yey akhir jugaa itzy itzyxultramilk dontstopyo...
# 137   Neutral       1.0  hasil buru photocard itzy ultra milk ryuryeong...
# 138   Neutral       1.0  bismillah habis ryujin itzy ultramilkxitzy don...
# 139   Neutral       1.0  out of more go ngomong-ngomong photocard kemba...
#
# [140 rows x 6 columns]

# %%
platform = 'ultramilk_initialize'

# Check Path is Available if no Create Dir
if path.exists(root_file+'/data/preprocess/'+platform) == False:
  os.makedirs(root_file+'/data/preprocess/'+platform)
else :
  print("File Already Existed")

# Export the Data
df_final.to_csv('data/preprocess/'+platform+'_mentionlytics.csv', encoding='utf-8', index=False)
df_final.to_excel('data/preprocess/'+platform+'_mentionlytics.xlsx', encoding='utf-8', index=False)
# Out:
# File Already Existed
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py:211: FutureWarning: the 'encoding' keyword is deprecated and will be removed in a future version. Please take steps to stop the use of 'encoding'
#   return func(*args, **kwargs)
