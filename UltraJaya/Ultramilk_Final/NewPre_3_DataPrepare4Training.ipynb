# %% [markdown]
# ## **Load Root Google Drive File dan Import Library**

# %%
## Load Folder Drive
import os, sys
from google.colab import drive
drive.mount('/content/drive/')

## Move Pointer File ke DATA_UM
# %cd /content/drive/MyDrive/DATA_UM

## Declare Root Project File
root_file = "/content/drive/MyDrive/DATA_UM"
# Out:
# Mounted at /content/drive/
# /content/drive/MyDrive/DATA_UM

# %%
# Import Important Library
import pandas as pd
import os.path
from os import path

# %% [markdown]
# ## **STRUCTURE CHANGES TO MATCH TRAINING DATA REQUIREMENT**

# %%
## Declare Hashtag Data
hashtag = "ultramilk_new_prepro"

# %%
# Load Data for Training
df = pd.read_excel('data/preprocess/'+hashtag+'_all.xlsx')

# Rename column previous index as id_tweet for reporting purposes
df.rename( columns={'Unnamed: 0':'id_tweet'}, inplace=True)

# Show Data
df
# Out:
#                       date   platform         brand                   hashtag  \
# 0               2023-10-27    Twitter     ultramilk          iamultraoddinary
# 1               2023-11-01    Twitter     ultramilk          iamultraoddinary
# 2               2023-11-01    Twitter     ultramilk              makeyourmove
# 3               2022-07-08    Twitter     ultramilk          dontstopyourmove
# 4               2022-07-08    Twitter     ultramilk  theunstoppablegeneration
# ...                    ...        ...           ...                       ...
# 15602  2022-03-25 00:00:00  Instagram  Manipulation              Manipulation
# 15603  2022-03-18 00:00:00  Instagram  Manipulation              Manipulation
# 15604  2022-03-15 00:00:00  Instagram  Manipulation              Manipulation
# 15605  2022-02-12 00:00:00  Instagram  Manipulation              Manipulation
# 15606  2022-02-12 00:00:00  Instagram  Manipulation              Manipulation
#
#                        name        username           profile_id  comments  \
# 0           Make Your Move!       @ultramym  1197372091978276864     279.0
# 1           Make Your Move!       @ultramym  1197372091978276864     526.0
# 2           Make Your Move!       @ultramym  1197372091978276864     526.0
# 3           Make Your Move!       @ultramym  1197372091978276864     329.0
# 4           Make Your Move!       @ultramym  1197372091978276864     329.0
# ...                     ...             ...                  ...       ...
# 15602                    울란       adlwulann                  Nan       NaN
# 15603  Melisa Kristianawati       melikris_                  Nan       NaN
# 15604                bila❤️  nabilahaysha10                  Nan       NaN
# 15605      BANG MISTER ALOY     mister.aloy                  Nan       NaN
# 15606                  Giar       giarmonie                  Nan       NaN
#
#        share_retweet  bookmark  quotes  likes  \
# 0            11687.0       0.0   933.0  49556
# 1            11012.0       0.0  2015.0  39385
# 2            11012.0       0.0  2015.0  39385
# 3             2862.0       0.0  1057.0  13633
# 4             2862.0       0.0  1057.0  13633
# ...              ...       ...     ...    ...
# 15602            NaN       NaN     NaN      0
# 15603            NaN       NaN     NaN      0
# 15604            NaN       NaN     NaN      0
# 15605            NaN       NaN     NaN      1
# 15606            NaN       NaN     NaN      1
#
#                                                     link  \
# 0      https://twitter.com/ultramym/status/1717890328...
# 1      https://twitter.com/ultramym/status/1719564927...
# 2      https://twitter.com/ultramym/status/1719564927...
# 3      https://twitter.com/ultramym/status/1545211062...
# 4      https://twitter.com/ultramym/status/1545211062...
# ...                                                  ...
# 15602           https://www.instagram.com/p/CZYc-oOh3Xv/
# 15603           https://www.instagram.com/p/CZYc-oOh3Xv/
# 15604           https://www.instagram.com/p/CZYc-oOh3Xv/
# 15605           https://www.instagram.com/p/CZYc-oOh3Xv/
# 15606           https://www.instagram.com/p/CZYc-oOh3Xv/
#
#                                                     text  labelling  \
# 0      Dengan bangga mempersembahkan @Stray_Kids seba...          4
# 1      Gimana ULTRAoddinary versi @Stray_Kids bareng ...          4
# 2      Gimana ULTRAoddinary versi @Stray_Kids bareng ...          4
# 3      Taraaaaa~ Ultra Milk dan @ITZYofficial mengaja...          4
# 4      Taraaaaa~ Ultra Milk dan @ITZYofficial mengaja...          4
# ...                                                  ...        ...
# 15602  @melikris_ ultramilk saya isinya oli bekas kak...          0
# 15603  Cek dm min,!! ultramilk saya ada sesuatu yg me...          0
# 15604  min ini gimana masa saya beli teh pucuk exp ma...          0
# 15605  saya di bohongi tmpt nasi padang, katanya sepa...          0
# 15606  Tolong jadiin @mr.aloyy_ BA @ultramym , karena...          0
#
#                                               text_final
# 0       bangga sembah bagai brand ambassador baru ult...
# 1      bagaimana ultraoddinary versi bareng ultra mil...
# 2      bagaimana ultraoddinary versi bareng ultra mil...
# 3      tara ultra milk ajak kamu buat jadi theunstopp...
# 4      tara ultra milk ajak kamu buat jadi theunstopp...
# ...                                                  ...
# 15602  ultramilk isi oli bekas kakak tapi tutup segel...
# 15603  cek dm admin ultramilk ada jijik pengin muntah...
# 15604  admin bagaimana masa beli teh pucuk exp lama k...
# 15605   bohong tempat nasi padang kata paket tolong k...
# 15606  tolong jadi brand ambassador dari storynya bel...
#
# [15607 rows x 16 columns]

# %% [markdown]
# ## **CREATE FOLDER AND EXPORT DATA**

# %%
# Check Path is Available if no Create Dir
if path.exists(root_file+'/data/training/'+hashtag) == False:
  os.makedirs(root_file+'/data/training/'+hashtag)
else :
  print("File Already Existed")
# Out:
# File Already Existed

# %%
# Export Data
df.to_csv('data/training/'+hashtag+'/'+hashtag+'_all.csv', index=False)
