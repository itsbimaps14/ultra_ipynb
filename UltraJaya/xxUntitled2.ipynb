# %%
import os, sys
from google.colab import drive
drive.mount('/content/drive/')
# %cd /content/drive/MyDrive/DATA_UM
# Out:
# Mounted at /content/drive/
# /content/drive/MyDrive/DATA_UM

# %%
# !pip install tiktok-hashtag-analysis
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 2.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 16.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.5/35.5 MB 43.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.4/194.4 kB 26.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 76.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 13.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 98.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 612.9/612.9 kB 55.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: greenlet
#     Found existing installation: greenlet 3.0.1
#     Uninstalling greenlet-3.0.1:
#       Successfully uninstalled greenlet-3.0.1
# ...

# %%
# !pip install TikTokApi

# %%
# !pip install playwright

# %%
# !tiktok-hashtag-analysis UltraMilkxStrayKids
# Out:
# 2023-11-17 02:06:11 INFO | Hashtags to scrape: ['ultramilkxstraykids']
# 2023-11-17 02:06:11 INFO | Writing data to directory: /root/tiktok_hashtag_data
# 2023-11-17 02:06:25 WARNING | Encountered error TikTokException.__init__() missing 2 required positional arguments: 'raw_response' and 'message' when fetching data, retrying in headed mode
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/tiktok_hashtag_analysis/base.py", line 182, in get_hashtag_posts
#     fetched_data = asyncio.run(
#   File "/usr/lib/python3.10/asyncio/runners.py", line 44, in run
#     return loop.run_until_complete(main)
#   File "/usr/lib/python3.10/asyncio/base_events.py", line 649, in run_until_complete
#     return future.result()
#   File "/usr/local/lib/python3.10/dist-packages/tenacity/_asyncio.py", line 88, in async_wrapped
#     return await fn(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/tenacity/_asyncio.py", line 47, in __call__
# ...
